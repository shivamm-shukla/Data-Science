# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Creating DataFrame**

# %%
# using lists

student_data = [
[100,80,10],
[90,70,7],
[120,100,14],
[80,50,2]
]

pd.DataFrame(student_data, columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dicts

student_dict = {
     'name':['shivam','shubham', 'shivangi','shubhangi','manish','manisha'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}

students = pd.DataFrame(student_dict)
students
# Out:
#         name   iq  marks  package
# 0     shivam  100     80       10
# 1    shubham   90     70        7
# 2   shivangi  120    100       14
# 3  shubhangi   80     50        2
# 4     manish    0      0        0
# 5    manisha    0      0        0

# %%
# set index without modifying actual dataframe

students.set_index('name')
# Out:
#             iq  marks  package
# name
# shivam     100     80       10
# shubham     90     70        7
# shivangi   120    100       14
# shubhangi   80     50        2
# manish       0      0        0
# manisha      0      0        0

# %%
# set index inplace
students.set_index('name', inplace=True)
students
# Out:
#             iq  marks  package
# name
# shivam     100     80       10
# shubham     90     70        7
# shivangi   120    100       14
# shubhangi   80     50        2
# manish       0      0        0
# manisha      0      0        0

# %%
# to reverse the inplace index set

students.reset_index(inplace=True)

# %%
# using read_csv
movies = pd.read_csv('movies.csv')
movies
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3873562259.py in <cell line: 0>()
#       1 # using read_csv
# ----> 2 movies = pd.read_csv('movies.csv')
#       3 movies
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'movies.csv'

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4000287082.py in <cell line: 0>()
# ----> 1 ipl = pd.read_csv('ipl-matches.csv')
#       2 ipl
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ipl-matches.csv'

# %% [markdown]
# # **DataFrame Attributes and Methods**

# %%
# shape

movies.shape

# %%
ipl.shape

# %%
# dtypes
movies.dtypes

# %%
ipl.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4106304774.py in <cell line: 0>()
# ----> 1 ipl.dtypes
#
# NameError: name 'ipl' is not defined

# %%
# index
movies.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3341626170.py in <cell line: 0>()
#       1 # index
# ----> 2 movies.index
#
# NameError: name 'movies' is not defined

# %%
# columns
movies.columns

# %%
ipl.columns

# %%
# values
students.values

# %%
ipl.values

# %%
# head and tail
movies.head()

# %%
movies.head(7)

# %%
ipl.tail()

# %%
ipl.tail(8)

# %%
# sample
ipl.sample(8)

# %%
# info
movies.info()

# %%
# describe
movies.describe()

# %%
# isnull
movies.isnull().sum()

# %%
# duplicated
movies.duplicated().sum()

# %%
#rename
students

# %%
students.rename(columns={'marks':'percent','package':'lpa'})

# %% [markdown]
# # **Math Methods**

# %%
# sum -> axis argument
students.sum(axis=0) # col wise

# %%
students

# %%
students.set_index('name', inplace=True)

# %%
# mean
students.mean(axis=1)

# %%
# var

students.var()

# %% [markdown]
# # **Selecting cols from DataFrame**

# %%
# single cols
movies['actors']

# %%
type(movies['actors'])

# %%
# multiple cols
movies[['year_of_release','actors','title_x']]

# %%
ipl[['Team1','Team2','WinningTeam']]

# %% [markdown]
# # **Selecting Rows from a DataFrame**
#
# *   **iloc -** searches using index positions
# *   **loc -** searches using index labels

# %%
# single row
movies.iloc[4]

# %%
movies

# %%
# multiple rows
movies.iloc[:5]

# %%
# fancy indexing

movies.iloc[[0,4,5]]

# %%
# loc

students

# %%
students.loc['shivam']

# %%
students.loc['shivam':'manisha': 2]

# %%
students.loc[['shivam', 'shivangi','shubhangi']]

# %% [markdown]
# # **Selecting both rows and cols**

# %%
movies.iloc[0:3,0:3]

# %%
movies.iloc[3,3]

# %%
movies.loc[0:2,'title_x':'poster_path']

# %% [markdown]
# # **Filtering a DataFrame**

# %%
ipl.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2751540211.py in <cell line: 0>()
# ----> 1 ipl.head()
#
# NameError: name 'ipl' is not defined

# %%
ipl.head(2)

# %%
# find all the final winners

mask = ipl['MatchNumber'] == 'Final'
new_df = ipl[mask]
new_df[['Season','WinningTeam']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4051028985.py in <cell line: 0>()
#       1 # find all the final winners
#       2
# ----> 3 mask = ipl['MatchNumber'] == 'Final'
#       4 new_df = ipl[mask]
#       5 new_df[['Season','WinningTeam']]
#
# NameError: name 'ipl' is not defined

# %%
# above thing can be done in one line too

ipl[ipl['MatchNumber'] == 'Final'] [['Season','WinningTeam']]

# %%
# How many super over finishes have occured
ipl.sample(3)

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1996354802.py in <cell line: 0>()
# ----> 1 ipl[ipl['SuperOver'] == 'Y'].shape[0]
#
# NameError: name 'ipl' is not defined

# %%
# How many matches has csk won in kolkata
ipl.head(2)

# %%
df = ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')]

# %%
df.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2152963384.py in <cell line: 0>()
# ----> 1 df.shape[0]
#
# NameError: name 'df' is not defined

# %%
# Toss winner is match winner in percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100

# %%
# movies with rating higher than 8 and votes>10000
movies.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1405546734.py in <cell line: 0>()
#       1 # movies with rating higher than 8 and votes>10000
# ----> 2 movies.head(3)
#
# NameError: name 'movies' is not defined

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]

# %%
# Action movies with rating higher than 7.5
movies.sample(5)

# %%
mask1 = movies['genres'].str.split('|').apply(lambda x: 'Action' in x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3220929696.py in <cell line: 0>()
# ----> 1 mask1 = movies['genres'].str.split('|').apply(lambda x: 'Action' in x)
#
# NameError: name 'movies' is not defined

# %%
mask2 = movies['imdb_rating'] > 7.5

# %%
movies[mask1 & mask2].shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2983260004.py in <cell line: 0>()
# ----> 1 movies[mask1 & mask2].shape[0]
#
# NameError: name 'movies' is not defined

# %%
# another way
mask3 = movies['genres'].str.contains('Action')
movies[mask2 & mask3].shape[0]

# %%
# Write a function that can return the track record of 2 teams against each other

# %% [markdown]
# # **Adding new cols**

# %%
# completely new
movies['country'] = 'India'
movies.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3390164083.py in <cell line: 0>()
#       1 # completely new
# ----> 2 movies['country'] = 'India'
#       3 movies.head()
#
# NameError: name 'movies' is not defined

# %% [markdown]
# # **Important Functions**

# %%
# astype
ipl.info()

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2920047894.py in <cell line: 0>()
# ----> 1 ipl.info()
#
# NameError: name 'ipl' is not defined

# %%
ipl['Season'] = ipl['Season'].astype('category')

# %%
ipl.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2920047894.py in <cell line: 0>()
# ----> 1 ipl.info()
#
# NameError: name 'ipl' is not defined
